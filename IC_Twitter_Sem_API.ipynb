# %% [markdown]
# # **[Package:twint](https://github.com/twintproject/twint)**
#
# * [How to use Twint as an OSINT tool](https://pielco11.ovh/posts/twint-osint/#introduction)
# * [Github: Tweet attributes](https://github.com/twintproject/twint/wiki/Tweet-attributes)
# * [Gitbut: Configuration Options](https://github.com/twintproject/twint/wiki/Configuration)
# * [Neal Caren](https://nealcaren.org/lessons/twint/)
# * [Naiara Cerqueira](https://naiaracerqueira.medium.com/twint-coleta-de-dados-do-twitter-com-python-dac3dec8a1c5)

# %%
# Before installation, it is helpful to make sure you have the most up-to-date version of conda
#%conda update -n base -c defaults conda

# %%
#%conda install -c conda-forge aiohttp  pysocks geopy googletrans cchardet nest-asyncio

# %%
# All requested packages already installed.
#------------------------------------------------------------------------------------------------------------------#

# %%
#%pip install twint

# %% [markdown]
# ## Scraping

# %%
# Aponta para pasta *****************************************************************************************************
import os
os.chdir("C:/Users/andre/OneDrive/EDUCAÇÃO/UNINOVE/Doutorado_ADM_2020/Iniciacao_Cientifica_PPGA/IC_Arquivos_para_Metodologia_Resultados")
# ***********************************************************************************************************************

# %%
import twint
import nest_asyncio

nest_asyncio.apply()

# %%
# Before searching, you need to configure the search parameters ********************************************************
c = twint.Config()

c.Search = '#paraisopolis'
c.Limit = 20

# The configuration parameters are passed to the `Search’ function.
twint.run.Search(c)
#***********************************************************************************************************************
# Out:
# 1373263802888753161 2021-03-20 10:22:59 -0300 <FelSabor> Parabéns #paraisopolis @brunocovas Veja esse exemplo.  https://t.co/pfav17JEje
# 1373121460559044610 2021-03-20 00:57:22 -0300 <deca_deca4> Tem festa na #paraisopolis???? É isso mesmo???? Som altissimo por aqui. Alo @jdoriajr @77_frota @PMESP @brunocovas @Estadao @folha
# 1371238155492397060 2021-03-14 20:13:47 -0300 <CanuttoKelly> #Paraisopólis #Melhornovela
# 1370493873462595584 2021-03-12 18:56:16 -0300 <pretoreliquia> A polícia sempre cercou e oprimiu a grande comunidade de Paraisópolis, gostaria de vê-los cercando e oprimindo Alphaville e nos condomínios de luxo.  #paraisopolis #favela #pandemia #COVID19 #joaodoria
# 1367107992269766658 2021-03-03 10:41:59 -0300 <SoNoticiaBoaSNB> Apoio, trabalho e sustento para famílias da comunidade.   https://t.co/HZ1MreA6gu  #sonoticiaboa #noticiaboa #fazenda #urbana #horta #comida #trabalho #apoio #sustento #familias #agricultura #comunidade #boaideia #paraisopolis #SaoPaulo
# ...

# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
# One storage solution is to output the results to a pandas dataframe **************************************************
c = twint.Config()

c.Search = '#paraisopolis'
c.Limit = 20
c.Pandas = True
#***********************************************************************************************************************

# %%
# Run the search again with the new setting ****************************************************************************
twint.run.Search(c)
#***********************************************************************************************************************
# Out:
# 1373263802888753161 2021-03-20 10:22:59 -0300 <FelSabor> Parabéns #paraisopolis @brunocovas Veja esse exemplo.  https://t.co/pfav17JEje
# 1373121460559044610 2021-03-20 00:57:22 -0300 <deca_deca4> Tem festa na #paraisopolis???? É isso mesmo???? Som altissimo por aqui. Alo @jdoriajr @77_frota @PMESP @brunocovas @Estadao @folha
# 1371238155492397060 2021-03-14 20:13:47 -0300 <CanuttoKelly> #Paraisopólis #Melhornovela
# 1370493873462595584 2021-03-12 18:56:16 -0300 <pretoreliquia> A polícia sempre cercou e oprimiu a grande comunidade de Paraisópolis, gostaria de vê-los cercando e oprimindo Alphaville e nos condomínios de luxo.  #paraisopolis #favela #pandemia #COVID19 #joaodoria
# 1367107992269766658 2021-03-03 10:41:59 -0300 <SoNoticiaBoaSNB> Apoio, trabalho e sustento para famílias da comunidade.   https://t.co/HZ1MreA6gu  #sonoticiaboa #noticiaboa #fazenda #urbana #horta #comida #trabalho #apoio #sustento #familias #agricultura #comunidade #boaideia #paraisopolis #SaoPaulo
# ...

# %%
# Sample of the responses **********************************************************************************************
df = twint.storage.panda.Tweets_df
df.sample(5)
#***********************************************************************************************************************
# Out:
#                      id      conversation_id    created_at  \
# 93  1321194962495643648  1321194962495643648  1.603832e+12
# 19  1358072917557321729  1358072917557321729  1.612625e+12
# 84  1329999629501542401  1329999629501542401  1.605932e+12
# 88  1325969163010142209  1325969163010142209  1.604971e+12
# 90  1323174421809500162  1323174421809500162  1.604304e+12
#
#                    date timezone place  \
# 93  2020-10-27 18:00:00    -0300
# 19  2021-02-06 12:19:49    -0300
# 84  2020-11-21 01:06:36    -0300
# 88  2020-11-09 22:10:58    -0300
# 90  2020-11-02 05:05:40    -0300
#
#                                                 tweet language  \
# 93  ✅O @fundosocialsp realiza curso de pintor na f...       pt
# 19  Brazil's ten largest favelas created a communi...       en
# 84  A exposição “O Silêncio que Grita”, inspirada ...       pt
# 88  Paraisópolis by @drone.leo 🚩 #saopaulocity #Eu...       pt
# 90  SP e sua burguesia fetida, nojenta, violenta, ...       pt
#
# ...

# %%
# The dataframe includes more information than was displayed **********************************************************
df.info()
#***********************************************************************************************************************
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               100 non-null    object
#  1   conversation_id  100 non-null    object
#  2   created_at       100 non-null    float64
#  3   date             100 non-null    object
#  4   timezone         100 non-null    object
#  5   place            100 non-null    object
#  6   tweet            100 non-null    object
#  7   language         100 non-null    object
#  8   hashtags         100 non-null    object
#  9   cashtags         100 non-null    object
#  10  user_id          100 non-null    int64
#  11  user_id_str      100 non-null    object
#  12  username         100 non-null    object
#  13  name             100 non-null    object
#  14  day              100 non-null    int64
#  15  hour             100 non-null    object
#  16  link             100 non-null    object
# ...

# %% [markdown]
# # #paraisopolis

# %%
# Store the results to a file in the JSON ******************************************************************************
import twint

c = twint.Config()
c.Search = '#paraisopolis'

c.Since = '2019-12-01'
c.Until = '2020-12-31'
c.Store_json = True
c.Output = "paraisopolis_2019.json"

twint.run.Search(c)
#***********************************************************************************************************************
# Out:
# 1343756467510370311 2020-12-29 00:11:22 -0300 <renatodsanto> Saudades rolê de natal!  #natal2020  #DZ7  #paraisopolis  https://t.co/zhhMdRvWlt
# 1343337896716230656 2020-12-27 20:28:07 -0300 <SerenaJoice> #Fantastico #paraisopolis “a ajuda do poder público ainda não chegou” *10* meses depois
# 1343016335119413250 2020-12-26 23:10:20 -0300 <projeto_spcity> Paraisópolis by @paraisopolis.foto 🚩 #saopaulocity #EuVivoSP #paraisopolis  https://t.co/98vaNEcVxm  https://t.co/blsww9Eoao
# 1340994109620834305 2020-12-21 09:14:44 -0300 <autotranscap> #FiqueAtento  Desde o último Sábado (19/12/20) 3 linhas de Paraisópolis mudaram seus pontos de partida, conforme destacado pela equipe da @gazetasp_   Confira:   https://t.co/L7zkp0QFru  #AutoViacaoTranscap #TransporteColetivo #Onibus #SP #Paraisopolis
# ...

# %%
# Info *****************************************************************************************************************
df = pd.read_json('paraisopolis_2019.json', lines = True)
df.info()
#***********************************************************************************************************************
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2868 entries, 0 to 2867
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2868 non-null   int64
#  1   conversation_id  2868 non-null   int64
#  2   created_at       2868 non-null   object
#  3   date             2868 non-null   datetime64[ns]
#  4   time             2868 non-null   object
#  5   timezone         2868 non-null   int64
#  6   user_id          2868 non-null   int64
#  7   username         2868 non-null   object
#  8   name             2868 non-null   object
#  9   place            2868 non-null   object
#  10  tweet            2868 non-null   object
#  11  language         2868 non-null   object
#  12  mentions         2868 non-null   object
#  13  urls             2868 non-null   object
#  14  photos           2868 non-null   object
#  15  replies_count    2868 non-null   int64
# ...

# %%
# Plotting the frequency by day ****************************************************************************************
# %matplotlib inline
df['date'].value_counts().plot()
#***********************************************************************************************************************

# %%
# Plotting the frequency including retweets ****************************************************************************
df['tweet_counts'] = df['retweets_count'] + 1
df.groupby(df["date"]).sum()["tweet_counts"].plot()
#***********************************************************************************************************************

# %%
# HTML to visualize the tweets *****************************************************************************************
from IPython.display import HTML
import requests

def show_tweet(link):
    '''Display the contents of a tweet. '''
    url = 'https://publish.twitter.com/oembed?url=%s' % link
    response = requests.get(url)
    html = response.json()["html"]
    display(HTML(html))
#***********************************************************************************************************************

# %%
# Function HTML test ***************************************************************************************************
sample_tweet_link = df.sample(1)['link'].values[0]
display(sample_tweet_link)
show_tweet(sample_tweet_link)
#***********************************************************************************************************************
# Out:
# 'https://twitter.com/MarlboroBoxx/status/1201542564370927616'
# <blockquote class="twitter-tweet"><p lang="pt" dir="ltr">Se sem o excludente de ilicitude, a PM de vários estados já pratica violência assim sem ser punidos, imagina com. <a href="https://twitter.com/hashtag/paraisopolis?src=hash&amp;ref_src=twsrc%5Etfw">#paraisopolis</a></p>&mdash; ᵛ ᵃ ˡ (@MarlboroBoxx) <a href="https://twitter.com/MarlboroBoxx/status/1201542564370927616?ref_src=twsrc%5Etfw">December 2, 2019</a></blockquote>
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>

# %%
# A list of the tweet urls, sorted by retweet count. *******************************************************************
rt_links = df.sort_values(by= 'retweets_count', ascending = False)['link'].values

for url in rt_links[:5]:
    print('🔥 ' * 19)
    show_tweet(url)
#***********************************************************************************************************************
# Out:
# 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥
# <blockquote class="twitter-tweet"><p lang="pt" dir="ltr">Massacre em <a href="https://twitter.com/hashtag/paraisopolis?src=hash&amp;ref_src=twsrc%5Etfw">#paraisopolis</a>. Os PMs encurralaram os jovens, nas vielas, espancaram, atiraram bombas. Foram às últimas consequências. Mataram os meninos que estavam dançando no baile funk. <a href="https://t.co/aDPXvgAmtZ">pic.twitter.com/aDPXvgAmtZ</a></p>&mdash; Jornalistas Livres (@J_LIVRES) <a href="https://twitter.com/J_LIVRES/status/1201247214280019968?ref_src=twsrc%5Etfw">December 1, 2019</a></blockquote>
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥 🔥
# ...

# %%
# Salve csv file *******************************************************************************************************
df.to_csv('paraisopolis2019.csv')
#***********************************************************************************************************************
